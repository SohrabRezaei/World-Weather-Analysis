# %%
import random

# %%
x=1
lat=[]
while x<2001:
    a=random.randint(-90,89)+random.random()
    lat.append(a)
    x+=1

# %%
x=1
lng=[]
while x<2001:
    a=random.randint(-180,179)+random.random()
    lng.append(a)
    x+=1

# %%
from citipy import citipy

# %%
lat_lng=zip(lat,lng)

# %%
lat_lng

# %%
coordinates=list(lat_lng)

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0],coordinate[1]).city_name)
# Out:
# longyearbyen
# hualmay
# cedar city
# batemans bay
# khatanga
# mataura
# rikitea
# kapaa
# kaitangata
# arraial do cabo
# barrow
# tuktoyaktuk
# burica
# imeni poliny osipenko
# klaksvik
# umzimvubu
# hermanus
# nizhniy tsasuchey
# kapaa
# moncton
# bluff
# albany
# punta arenas
# belushya guba
# hobart
# grand river south east
# paita
# atuona
# tuatapere
# atar
# plettenberg bay
# dingle
# ushuaia
# new norfolk
# thompson
# payo
# fonte boa
# coari
# barcelos
# boyolangu
# bobonong
# ntcheu
# vaini
# kaitangata
# illoqqortoormiut
# bam
# attawapiskat
# punta arenas
# along
# dwarka
# hermanus
# thompson
# port moresby
# monastyrshchina
# butaritari
# rikitea
# kaitangata
# barentsburg
# itoman
# esperance
# saskylakh
# thompson
# kavieng
# ushuaia
# vaini
# the valley
# barrow
# grand river south east
# fortuna
# kapaa
# port elizabeth
# boddam
# ranong
# mar del plata
# albany
# mayo
# barrow
# illoqqortoormiut
# barentsburg
# bluff
# faanui
# tuatapere
# atuona
# saint anthony
# ...

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 771

# %%
from config import g_key

# %%
import json
import requests
import time

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?&APPID={g_key}&units=imperial"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country= city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | cedar city
# Processing Record 4 of Set 1 | batemans bay
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | burica
# City not found. Skipping...
# Processing Record 14 of Set 1 | imeni poliny osipenko
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | nizhniy tsasuchey
# Processing Record 19 of Set 1 | moncton
# ...

# %%
city_weather
# Out:
# {'coord': {'lon': -101.865, 'lat': 54.7682},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13d'}],
#  'base': 'stations',
#  'main': {'temp': 3.04,
#   'feels_like': -9.56,
#   'temp_min': 3.04,
#   'temp_max': 3.04,
#   'pressure': 997,
#   'humidity': 72},
#  'visibility': 3219,
#  'wind': {'speed': 11.5, 'deg': 20, 'gust': 21.85},
#  'snow': {'1h': 0.16},
#  'clouds': {'all': 100},
#  'dt': 1644525786,
#  'sys': {'type': 1,
#   'id': 782,
#   'country': 'CA',
#   'sunrise': 1644502793,
#   'sunset': 1644536619},
#  'timezone': -21600,
#  'id': 5954718,
#  'name': 'Flin Flon',
#  'cod': 200}

# %%
import pandas as pd
city_data_df=pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Longyearbyen      SJ  78.2186   15.6401     24.64        68
# 1               Hualmay      PE -11.0964  -77.6139     74.39        69
# 2            Cedar City      US  37.6775 -113.0619     50.40        40
# 3          Batemans Bay      AU -35.7167  150.1833     67.19        83
# 4              Khatanga      RU  71.9667  102.5000     -5.48        97
# ..                  ...     ...      ...       ...       ...       ...
# 704             Shihezi      CN  44.3000   86.0333     13.93        97
# 705             Cascais      PT  38.6979   -9.4215     60.15        72
# 706         Broken Hill      AU -31.9500  141.4333     60.51        59
# 707  Sao Felix Do Xingu      BR  -6.6447  -51.9950     76.71        96
# 708           Flin Flon      CA  54.7682 -101.8650      3.04        72
#
#      Cloudiness  Wind Speed      Description
# 0            75        8.05    broken clouds
# ...

# %%
export_file="WeatherPy_Database.csv"
city_data_df.to_csv(export_file,index_label='City ID')
